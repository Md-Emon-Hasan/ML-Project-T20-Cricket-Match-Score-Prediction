# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('data/t20i_info.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed city                     venue
# 0                0  NaN  Melbourne Cricket Ground
# 1                0  NaN  Melbourne Cricket Ground
# 2                0  NaN  Melbourne Cricket Ground
# 3                0  NaN  Melbourne Cricket Ground
# 4                0  NaN  Melbourne Cricket Ground

# %%
df.head(2)
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
#
#   player_dismissed city                     venue
# 0                0  NaN  Melbourne Cricket Ground
# 1                0  NaN  Melbourne Cricket Ground

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df.shape
# Out:
# (63888, 9)

# %% [markdown]
# * Batting team
# * Bowling team
# * City
# * Current score
# * Balls left
# * Wicket left
# * Current run rate
# * Last five/six->powerplay

# %%
# df[df['city'].isnull()]['venue'][0].split(' ')[0]

# %%
# df['city'] = df['city'].fillna(df['venue'].apply(lambda x:x.split(' ')[0]))

# %%
df.tail()
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed     city                venue
# 63883                0  Colombo  R Premadasa Stadium
# 63884                0  Colombo  R Premadasa Stadium
# 63885      DM de Silva  Colombo  R Premadasa Stadium
# 63886                0  Colombo  R Premadasa Stadium
# 63887                0  Colombo  R Premadasa Stadium

# %%
df['batting_team'].unique()
# Out:
# array(['Australia', 'New Zealand', 'South Africa', 'England', 'India',
#        'West Indies', 'Pakistan', 'Bangladesh', 'Afghanistan',
#        'Sri Lanka'], dtype=object)

# %%
df['venue'].unique()
# Out:
# array(['Melbourne Cricket Ground', 'Simonds Stadium, South Geelong',
#        'Adelaide Oval', 'McLean Park', 'Bay Oval', 'Eden Park',
#        'The Rose Bowl', 'County Ground', 'Sophia Gardens',
#        'Riverside Ground', 'Green Park',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'M Chinnaswamy Stadium',
#        'Central Broward Regional Park Stadium Turf Ground',
#        'Dubai International Cricket Stadium', 'Sheikh Zayed Stadium',
#        'Sydney Cricket Ground', 'Bellerive Oval', 'Westpac Stadium',
#        'Seddon Park', 'Mangaung Oval', 'Senwes Park',
#        'Kensington Oval, Bridgetown', "Queen's Park Oval, Port of Spain",
#        'R Premadasa Stadium', 'Warner Park, Basseterre',
#        'Sabina Park, Kingston', 'R.Premadasa Stadium, Khettarama',
#        'Saxton Oval', 'JSCA International Stadium Complex', 'Edgbaston',
#        'Old Trafford', 'Arun Jaitley Stadium',
#        'Saurashtra Cricket Association Stadium',
# ...

# %%
df['venue'].nunique()
# Out:
# 94

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df['venue'].value_counts()
# Out:
# venue
# Shere Bangla National Stadium          3420
# R Premadasa Stadium                    2983
# Dubai International Cricket Stadium    2969
# New Wanderers Stadium                  2819
# Eden Park                              2532
#                                        ...
# Senwes Park                             122
# Hagley Oval                             121
# Subrata Roy Sahara Stadium              121
# Sardar Patel Stadium, Motera            121
# Carrara Oval                             64
# Name: count, Length: 94, dtype: int64

# %%
df['city'].nunique()
# Out:
# 81

# %%
# eligible_cites = df['city'].value_counts()[df['city'].value_counts() > 500].index.tolist()
eligible_venue = df['venue'].value_counts()[df['venue'].value_counts() > 480].index.tolist()

# %%
# eligible_cites
eligible_venue
# Out:
# ['Shere Bangla National Stadium',
#  'R Premadasa Stadium',
#  'Dubai International Cricket Stadium',
#  'New Wanderers Stadium',
#  'Eden Park',
#  'Newlands',
#  'Pallekele International Cricket Stadium',
#  'Kensington Oval, Bridgetown',
#  'Melbourne Cricket Ground',
#  'Beausejour Stadium, Gros Islet',
#  'Kennington Oval',
#  'Kingsmead',
#  'Westpac Stadium',
#  'Central Broward Regional Park Stadium Turf Ground',
#  'Seddon Park',
#  'SuperSport Park',
#  'Old Trafford',
#  'Zahur Ahmed Chowdhury Stadium',
#  'R.Premadasa Stadium, Khettarama',
#  'Sheikh Zayed Stadium',
#  'Sydney Cricket Ground',
#  'Trent Bridge',
#  'The Rose Bowl',
#  'Bay Oval',
#  'Wankhede Stadium',
#  'Eden Gardens',
#  'Gaddafi Stadium',
#  'Vidarbha Cricket Association Stadium, Jamtha',
#  "Lord's",
#  'Adelaide Oval',
#  'M Chinnaswamy Stadium',
#  'Warner Park, Basseterre',
#  'Sophia Gardens',
#  "Queen's Park Oval, Port of Spain",
#  'Brisbane Cricket Ground, Woolloongabba',
#  'Edgbaston',
# ...

# %%
# print(eligible_cites)
print(eligible_venue)
# Out:
# ['Shere Bangla National Stadium', 'R Premadasa Stadium', 'Dubai International Cricket Stadium', 'New Wanderers Stadium', 'Eden Park', 'Newlands', 'Pallekele International Cricket Stadium', 'Kensington Oval, Bridgetown', 'Melbourne Cricket Ground', 'Beausejour Stadium, Gros Islet', 'Kennington Oval', 'Kingsmead', 'Westpac Stadium', 'Central Broward Regional Park Stadium Turf Ground', 'Seddon Park', 'SuperSport Park', 'Old Trafford', 'Zahur Ahmed Chowdhury Stadium', 'R.Premadasa Stadium, Khettarama', 'Sheikh Zayed Stadium', 'Sydney Cricket Ground', 'Trent Bridge', 'The Rose Bowl', 'Bay Oval', 'Wankhede Stadium', 'Eden Gardens', 'Gaddafi Stadium', 'Vidarbha Cricket Association Stadium, Jamtha', "Lord's", 'Adelaide Oval', 'M Chinnaswamy Stadium', 'Warner Park, Basseterre', 'Sophia Gardens', "Queen's Park Oval, Port of Spain", 'Brisbane Cricket Ground, Woolloongabba', 'Edgbaston', 'Mahinda Rajapaksa International Cricket Stadium, Sooriyawewa', 'Shere Bangla National Stadium, Mirpur', 'The
# ...

# %%
print(len(eligible_venue))
# Out:
# 45

# %%
# df = df[df['city'].isin(eligible_cites)]
df = df[df['venue'].isin(eligible_venue)]

# %%
df.shape
# Out:
# (53469, 9)

# %%
df['venue'].nunique()
# Out:
# 45

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed city                     venue
# 0                0  NaN  Melbourne Cricket Ground
# 1                0  NaN  Melbourne Cricket Ground
# 2                0  NaN  Melbourne Cricket Ground
# 3                0  NaN  Melbourne Cricket Ground
# 4                0  NaN  Melbourne Cricket Ground

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed city                     venue  current_score
# 0                0  NaN  Melbourne Cricket Ground              0
# 1                0  NaN  Melbourne Cricket Ground              0
# 2                0  NaN  Melbourne Cricket Ground              1
# 3                0  NaN  Melbourne Cricket Ground              3
# 4                0  NaN  Melbourne Cricket Ground              3

# %%
df.tail()
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed     city                venue  current_score
# 63883                0  Colombo  R Premadasa Stadium            125
# 63884                0  Colombo  R Premadasa Stadium            125
# 63885      DM de Silva  Colombo  R Premadasa Stadium            125
# 63886                0  Colombo  R Premadasa Stadium            127
# 63887                0  Colombo  R Premadasa Stadium            128

# %%
df['ball_no'] = df['ball'].apply(lambda x:str(x).split('.')[1])
df['over'] = df['ball'].apply(lambda x:str(x).split('.')[0])

# %%
df.head(7)
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
# 5           5         2    Australia    Sri Lanka   0.6     3
# 6           6         2    Australia    Sri Lanka   1.1     0
#
#   player_dismissed city                     venue  current_score ball_no over
# 0                0  NaN  Melbourne Cricket Ground              0       1    0
# 1                0  NaN  Melbourne Cricket Ground              0       2    0
# 2                0  NaN  Melbourne Cricket Ground              1       3    0
# 3                0  NaN  Melbourne Cricket Ground              3       4    0
# 4                0  NaN  Melbourne Cricket Ground              3       5    0
# ...

# %%
df['ball_bowled'] = (df['over'].astype(int)*6 + df['ball_no'].astype(int))

# %%
df.head(7)
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
# 5           5         2    Australia    Sri Lanka   0.6     3
# 6           6         2    Australia    Sri Lanka   1.1     0
#
#   player_dismissed city                     venue  current_score ball_no over  \
# 0                0  NaN  Melbourne Cricket Ground              0       1    0
# 1                0  NaN  Melbourne Cricket Ground              0       2    0
# 2                0  NaN  Melbourne Cricket Ground              1       3    0
# 3                0  NaN  Melbourne Cricket Ground              3       4    0
# 4                0  NaN  Melbourne Cricket Ground              3       5    0
# ...

# %%
df['ball_left'] = 120 - df['ball_bowled']

# %%
df.tail()
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed     city                venue  current_score ball_no  \
# 63883                0  Colombo  R Premadasa Stadium            125       3
# 63884                0  Colombo  R Premadasa Stadium            125       4
# 63885      DM de Silva  Colombo  R Premadasa Stadium            125       5
# 63886                0  Colombo  R Premadasa Stadium            127       6
# 63887                0  Colombo  R Premadasa Stadium            128       7
#
#       over  ball_bowled  ball_left
# 63883   19          117          3
# 63884   19          118          2
# ...

# %%
df['ball_left'] = df['ball_left'].apply(lambda x:0 if x<0 else x)

# %%
df.tail()
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed     city                venue  current_score ball_no  \
# 63883                0  Colombo  R Premadasa Stadium            125       3
# 63884                0  Colombo  R Premadasa Stadium            125       4
# 63885      DM de Silva  Colombo  R Premadasa Stadium            125       5
# 63886                0  Colombo  R Premadasa Stadium            127       6
# 63887                0  Colombo  R Premadasa Stadium            128       7
#
#       over  ball_bowled  ball_left
# 63883   19          117          3
# 63884   19          118          2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53469 entries, 0 to 63887
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        53469 non-null  int64
#  1   match_id          53469 non-null  int64
#  2   batting_team      53469 non-null  object
#  3   bowling_team      53469 non-null  object
#  4   ball              53469 non-null  float64
#  5   runs              53469 non-null  int64
#  6   player_dismissed  53469 non-null  object
#  7   city              45734 non-null  object
#  8   venue             53469 non-null  object
#  9   current_score     53469 non-null  int64
#  10  ball_no           53469 non-null  object
#  11  over              53469 non-null  object
#  12  ball_bowled       53469 non-null  int32
#  13  ball_left         53469 non-null  int64
# dtypes: float64(1), int32(1), int64(5), object(7)
# memory usage: 5.9+ MB

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:1 if x!='0' else '0')

# %%
df.tail(7)
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 63881         119       964    Sri Lanka    Australia  19.1     1
# 63882         120       964    Sri Lanka    Australia  19.2     0
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed     city                venue  current_score ball_no  \
# 63881                0  Colombo  R Premadasa Stadium            124       1
# 63882                0  Colombo  R Premadasa Stadium            124       2
# 63883                0  Colombo  R Premadasa Stadium            125       3
# 63884                0  Colombo  R Premadasa Stadium            125       4
# ...

# %%
df.shape
# Out:
# (53469, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53469 entries, 0 to 63887
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        53469 non-null  int64
#  1   match_id          53469 non-null  int64
#  2   batting_team      53469 non-null  object
#  3   bowling_team      53469 non-null  object
#  4   ball              53469 non-null  float64
#  5   runs              53469 non-null  int64
#  6   player_dismissed  53469 non-null  object
#  7   city              45734 non-null  object
#  8   venue             53469 non-null  object
#  9   current_score     53469 non-null  int64
#  10  ball_no           53469 non-null  object
#  11  over              53469 non-null  object
#  12  ball_bowled       53469 non-null  int32
#  13  ball_left         53469 non-null  int64
# dtypes: float64(1), int32(1), int64(5), object(7)
# memory usage: 5.9+ MB

# %%
df['player_dismissed'] = df['player_dismissed'].astype(int)

# %%
df['cumulative_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()

# %%
df['wicket_left'] = 10 - df['player_dismissed']

# %%
df.tail(5)
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed     city                venue  current_score ball_no  \
# 63883                 0  Colombo  R Premadasa Stadium            125       3
# 63884                 0  Colombo  R Premadasa Stadium            125       4
# 63885                 1  Colombo  R Premadasa Stadium            125       5
# 63886                 0  Colombo  R Premadasa Stadium            127       6
# 63887                 0  Colombo  R Premadasa Stadium            128       7
#
#       over  ball_bowled  ball_left  cumulative_dismissed  wicket_left
# ...

# %%
df['current_run_rate'] = (df['current_score']*6)/df['ball_bowled']

# %%
df.tail()
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed     city                venue  current_score ball_no  \
# 63883                 0  Colombo  R Premadasa Stadium            125       3
# 63884                 0  Colombo  R Premadasa Stadium            125       4
# 63885                 1  Colombo  R Premadasa Stadium            125       5
# 63886                 0  Colombo  R Premadasa Stadium            127       6
# 63887                 0  Colombo  R Premadasa Stadium            128       7
#
#       over  ball_bowled  ball_left  cumulative_dismissed  wicket_left  \
# ...

# %%
# group by 'match id'
groups = df.groupby('match_id')

# 5 over = 30 balls
match_id = df['match_id'].unique()
last_five = []

for id in match_id:
    # Apply rolling sum on the 'runs' column
    rolling_sums = groups.get_group(id)['runs'].rolling(window=30).sum()
    last_five.extend(rolling_sums.values.tolist())

# %%
df['last_five'] = last_five

# %%
df['last_five']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 63883    32.0
# 63884    32.0
# 63885    32.0
# 63886    33.0
# 63887    32.0
# Name: last_five, Length: 53469, dtype: float64

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#    player_dismissed city                     venue  current_score ball_no  \
# 0                 0  NaN  Melbourne Cricket Ground              0       1
# 1                 0  NaN  Melbourne Cricket Ground              0       2
# 2                 0  NaN  Melbourne Cricket Ground              1       3
# 3                 0  NaN  Melbourne Cricket Ground              3       4
# 4                 0  NaN  Melbourne Cricket Ground              3       5
#
#   over  ball_bowled  ball_left  cumulative_dismissed  wicket_left  \
# 0    0            1        119                     0           10
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#        player_dismissed     city                venue  current_score ball_no  \
# 63883                 0  Colombo  R Premadasa Stadium            125       3
# 63884                 0  Colombo  R Premadasa Stadium            125       4
# 63885                 1  Colombo  R Premadasa Stadium            125       5
# 63886                 0  Colombo  R Premadasa Stadium            127       6
# 63887                 0  Colombo  R Premadasa Stadium            128       7
#
#       over  ball_bowled  ball_left  cumulative_dismissed  wicket_left  \
# ...

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df.head()
# Out:
#    match_id  runs_x  Unnamed: 0 batting_team bowling_team  ball  runs_y  \
# 0         2     168           0    Australia    Sri Lanka   0.1       0
# 1         2     168           1    Australia    Sri Lanka   0.2       0
# 2         2     168           2    Australia    Sri Lanka   0.3       1
# 3         2     168           3    Australia    Sri Lanka   0.4       2
# 4         2     168           4    Australia    Sri Lanka   0.5       0
#
#    player_dismissed city                     venue  current_score ball_no  \
# 0                 0  NaN  Melbourne Cricket Ground              0       1
# 1                 0  NaN  Melbourne Cricket Ground              0       2
# 2                 0  NaN  Melbourne Cricket Ground              1       3
# 3                 0  NaN  Melbourne Cricket Ground              3       4
# 4                 0  NaN  Melbourne Cricket Ground              3       5
#
#   over  ball_bowled  ball_left  cumulative_dismissed  wicket_left  \
# ...

# %%
df['batting_team'].nunique()
# Out:
# 10

# %%
final_df.head(3)
# Out:
#    match_id  runs_x  Unnamed: 0 batting_team bowling_team  ball  runs_y  \
# 0         2     168           0    Australia    Sri Lanka   0.1       0
# 1         2     168           1    Australia    Sri Lanka   0.2       0
# 2         2     168           2    Australia    Sri Lanka   0.3       1
#
#    player_dismissed city                     venue  current_score ball_no  \
# 0                 0  NaN  Melbourne Cricket Ground              0       1
# 1                 0  NaN  Melbourne Cricket Ground              0       2
# 2                 0  NaN  Melbourne Cricket Ground              1       3
#
#   over  ball_bowled  ball_left  cumulative_dismissed  wicket_left  \
# 0    0            1        119                     0           10
# 1    0            2        118                     0           10
# 2    0            3        117                     0           10
#
#    current_run_rate  last_five
# 0               0.0        NaN
# 1               0.0        NaN
# ...

# %%
final_df.columns
# Out:
# Index(['match_id', 'runs_x', 'Unnamed: 0', 'batting_team', 'bowling_team',
#        'ball', 'runs_y', 'player_dismissed', 'city', 'venue', 'current_score',
#        'ball_no', 'over', 'ball_bowled', 'ball_left', 'cumulative_dismissed',
#        'wicket_left', 'current_run_rate', 'last_five'],
#       dtype='object')

# %%
final_df = final_df[['batting_team', 'bowling_team', 'venue', 'current_score', 'ball_left', 'wicket_left', 'current_run_rate', 'last_five', 'runs_x']]

# %%
final_df.isnull().sum()
# Out:
# batting_team            0
# bowling_team            0
# venue                   0
# current_score           0
# ball_left               0
# wicket_left             0
# current_run_rate        0
# last_five           12749
# runs_x                  0
# dtype: int64

# %%
# replacing null value with for last_five column by mean
# final_df['last_five'] = final_df['last_five'].fillna(final_df['last_five'].mean())
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team        0
# bowling_team        0
# venue               0
# current_score       0
# ball_left           0
# wicket_left         0
# current_run_rate    0
# last_five           0
# runs_x              0
# dtype: int64

# %%
final_df.shape
# Out:
# (40720, 9)

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.head(3)
# Out:
#       batting_team  bowling_team                  venue  current_score  \
# 18837     Pakistan     Sri Lanka  New Wanderers Stadium             86
# 35480     Pakistan     Australia    R Premadasa Stadium            126
# 5547         India  South Africa               Newlands            105
#
#        ball_left  wicket_left  current_run_rate  last_five  runs_x
# 18837         51           10          7.478261       51.0     189
# 35480         14           10          7.132075       38.0     149
# 5547          45           10          8.400000       42.0     172

# %%
x = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train
# Out:
#       batting_team bowling_team  \
# 1603   West Indies     Pakistan
# 8588    Bangladesh  West Indies
# 47877        India    Australia
# 20359        India    Australia
# 50886  New Zealand     Pakistan
# ...            ...          ...
# 38644    Australia     Pakistan
# 42345     Pakistan    Australia
# 33877     Pakistan  New Zealand
# 25202   Bangladesh  West Indies
# 22376      England     Pakistan
#
#                                                    venue  current_score  \
# 1603                 Dubai International Cricket Stadium            103
# 8588   Central Broward Regional Park Stadium Turf Ground             66
# 47877                           Melbourne Cricket Ground            138
# 20359                           Melbourne Cricket Ground             63
# 50886  Punjab Cricket Association IS Bindra Stadium, ...            116
# ...                                                  ...            ...
# ...

# %%
# import machine learnign algorithm
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBRegressor

# %%
# initial classifier
lr = LinearRegression()
dt = DecisionTreeClassifier(max_depth=5)
rf = RandomForestClassifier(n_estimators=50,random_state=2,max_depth=5)
xr = XGBRegressor(n_estimators=1000, learning_rate=0.2, max_depth=12, random_state=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
transformer = ColumnTransformer([
    ('transformer', OneHotEncoder(drop='first', sparse_output=False), ['batting_team', 'bowling_team', 'venue'])
], remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1', transformer),
    ('step2', StandardScaler(with_mean=False)),
    ('step3', XGBRegressor(n_estimators=1000, learning_rate=0.2, max_depth=12, random_state=1))
])

# %%
pipe.fit(x_train,y_train)
# Out:
# c:\Program Files\Python311\Lib\site-packages\sklearn\compose\_column_transformer.py:1624: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('transformer',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
# ...

# %%
y_pred = pipe.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9803237915039062

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 2.0166356579493914

# %%
import pickle

# %%
pickle.dump(pipe,open('model.pkl','wb'))
